# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        DATE  LATITUDE_A  LONGITUDE_A  ELEVATION_A  PRCP_A  \
# 0           0  01-11-1979       63.88        77.52          128     NaN
# 1           1  13-11-1979       63.88        77.52          128     NaN
# 2           2  05-02-1980       63.88        77.52          128     NaN
# 3           3  23-12-1979       63.88        77.52          128     0.0
# 4           4  07-06-1977       63.88        77.52          128     NaN
#
#    SNWD_A  TMAX_A  TMIN_A  TAVG_A  ...  LONGITUDE_C  ELEVATION_C  PRCP_C  \
# 0     0.0    17.6     NaN   12.96  ...        78.93           64     0.0
# 1     0.0     8.8     NaN    0.00  ...        78.93           64     0.0
# 2     0.0    -9.9     NaN  -17.76  ...        78.93           64     0.0
# 3     0.0     NaN   -4.30   -4.44  ...        78.93           64     0.0
# 4     0.0    39.6   15.48     NaN  ...        78.93           64     NaN
#
#    SNWD_C  TMAX_C  TMIN_C  TAVG_C  LATITUDE  LONGITUDE  TAVG
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    LATITUDE_A   LONGITUDE_A  ELEVATION_A      PRCP_A  \
# count  812.000000  8.120000e+02  8.120000e+02        812.0  251.000000
# mean   405.500000  6.388000e+01  7.752000e+01        128.0    6.633466
# std    234.548502  7.109807e-15  1.421961e-14          0.0   38.496768
# min      0.000000  6.388000e+01  7.752000e+01        128.0    0.000000
# 25%    202.750000  6.388000e+01  7.752000e+01        128.0    0.000000
# 50%    405.500000  6.388000e+01  7.752000e+01        128.0    0.000000
# 75%    608.250000  6.388000e+01  7.752000e+01        128.0    0.000000
# max    811.000000  6.388000e+01  7.752000e+01        128.0  500.000000
#
#            SNWD_A      TMAX_A      TMIN_A      TAVG_A    LATITUDE_B  ...  \
# count  812.000000  567.000000  289.000000  742.000000  8.120000e+02  ...
# mean     0.215961   17.127795    8.385779   12.793423  6.295000e+01  ...
# std      0.787311   18.738273   15.991607   20.119547  7.109807e-15  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   812 non-null    int64
#  1   DATE         812 non-null    object
#  2   LATITUDE_A   812 non-null    float64
#  3   LONGITUDE_A  812 non-null    float64
#  4   ELEVATION_A  812 non-null    int64
#  5   PRCP_A       251 non-null    float64
#  6   SNWD_A       812 non-null    float64
#  7   TMAX_A       567 non-null    float64
#  8   TMIN_A       289 non-null    float64
#  9   TAVG_A       742 non-null    float64
#  10  LATITUDE_B   812 non-null    float64
#  11  LONGITUDE_B  812 non-null    float64
#  12  ELEVATION_B  812 non-null    int64
#  13  PRCP_B       812 non-null    int64
#  14  SNWD_B       812 non-null    float64
#  15  TMAX_B       812 non-null    float64
#  16  TMIN_B       812 non-null    float64
#  17  TAVG_B       742 non-null    float64
# ...

# %%
data.notnull().sum()
# Out:
# Unnamed: 0     812
# DATE           812
# LATITUDE_A     812
# LONGITUDE_A    812
# ELEVATION_A    812
# PRCP_A         251
# SNWD_A         812
# TMAX_A         567
# TMIN_A         289
# TAVG_A         742
# LATITUDE_B     812
# LONGITUDE_B    812
# ELEVATION_B    812
# PRCP_B         812
# SNWD_B         812
# TMAX_B         812
# TMIN_B         812
# TAVG_B         742
# LATITUDE_C     812
# LONGITUDE_C    812
# ELEVATION_C    812
# PRCP_C         605
# SNWD_C         812
# TMAX_C         573
# TMIN_C         341
# TAVG_C         683
# LATITUDE       812
# LONGITUDE      812
# TAVG           812
# dtype: int64

# %%
data.shape
# Out:
# (812, 29)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'DATE', 'LATITUDE_A', 'LONGITUDE_A', 'ELEVATION_A',
#        'PRCP_A', 'SNWD_A', 'TMAX_A', 'TMIN_A', 'TAVG_A', 'LATITUDE_B',
#        'LONGITUDE_B', 'ELEVATION_B', 'PRCP_B', 'SNWD_B', 'TMAX_B', 'TMIN_B',
#        'TAVG_B', 'LATITUDE_C', 'LONGITUDE_C', 'ELEVATION_C', 'PRCP_C',
#        'SNWD_C', 'TMAX_C', 'TMIN_C', 'TAVG_C', 'LATITUDE', 'LONGITUDE',
#        'TAVG'],
#       dtype='object')

# %%
data.notnull()
# Out:
#      Unnamed: 0  DATE  LATITUDE_A  LONGITUDE_A  ELEVATION_A  PRCP_A  SNWD_A  \
# 0          True  True        True         True         True   False    True
# 1          True  True        True         True         True   False    True
# 2          True  True        True         True         True   False    True
# 3          True  True        True         True         True    True    True
# 4          True  True        True         True         True   False    True
# ..          ...   ...         ...          ...          ...     ...     ...
# 807        True  True        True         True         True   False    True
# 808        True  True        True         True         True   False    True
# 809        True  True        True         True         True   False    True
# 810        True  True        True         True         True    True    True
# 811        True  True        True         True         True   False    True
#
# ...

# %%
data['PRCP_A'] = data['PRCP'].fillna(data['PRCP'].mean())

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# DATE             0
# LATITUDE_A       0
# LONGITUDE_A      0
# ELEVATION_A      0
# PRCP_A         561
# SNWD_A           0
# TMAX_A         245
# TMIN_A         523
# TAVG_A          70
# LATITUDE_B       0
# LONGITUDE_B      0
# ELEVATION_B      0
# PRCP_B           0
# SNWD_B           0
# TMAX_B           0
# TMIN_B           0
# TAVG_B          70
# LATITUDE_C       0
# LONGITUDE_C      0
# ELEVATION_C      0
# PRCP_C         207
# SNWD_C           0
# TMAX_C         239
# TMIN_C         471
# TAVG_C         129
# LATITUDE         0
# LONGITUDE        0
# TAVG             0
# dtype: int64
