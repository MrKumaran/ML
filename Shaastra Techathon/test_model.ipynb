# %%
import pandas as pd

# %%
df =pd.read_csv('train.csv')

# %%
df.dropna(inplace=True)

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 17 to 801
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         16 non-null     object
#  1   LATITUDE_A   16 non-null     float64
#  2   LONGITUDE_A  16 non-null     float64
#  3   ELEVATION_A  16 non-null     int64
#  4   PRCP_A       16 non-null     float64
#  5   SNWD_A       16 non-null     float64
#  6   TMAX_A       16 non-null     float64
#  7   TMIN_A       16 non-null     float64
#  8   TAVG_A       16 non-null     float64
#  9   LATITUDE_B   16 non-null     float64
#  10  LONGITUDE_B  16 non-null     float64
#  11  ELEVATION_B  16 non-null     int64
#  12  PRCP_B       16 non-null     int64
#  13  SNWD_B       16 non-null     float64
#  14  TMAX_B       16 non-null     float64
#  15  TMIN_B       16 non-null     float64
#  16  TAVG_B       16 non-null     float64
#  17  LATITUDE_C   16 non-null     float64
#  18  LONGITUDE_C  16 non-null     float64
#  19  ELEVATION_C  16 non-null     int64
#  20  PRCP_C       16 non-null     float64
#  21  SNWD_C       16 non-null     float64
#  22  TMAX_C       16 non-null     float64
#  23  TMIN_C       16 non-null     float64
#  24  TAVG_C       16 non-null     float64
#  25  LATITUDE     16 non-null     float64
#  26  LONGITUDE    16 non-null     float64
#  27  TAVG         16 non-null     float64
# dtypes: float64(23), int64(4), object(1)
# memory usage: 3.6+ KB

# %%
from sklearn.model_selection import train_test_split

X, Y = df.drop(['TAVG', 'DATE'], axis=1), df['TAVG']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
train = X_train.join(y_train)

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.9042544826453797

# %%
test = pd.read_csv('test.csv')

# %%
test.dropna(inplace=True)

# %%
X_test = test.drop(['DATE','INDEX'], axis=1)
y_pred = forest.predict(X_test)

# %%
y_pred
# Out:
# array([25.998, 11.54 ,  9.612, 21.715, 13.857, -4.486])

# %%
test['TAVG'] = y_pred

# %%
test['TAVG']
# Out:
# 17     25.998
# 81     11.540
# 132     9.612
# 135    21.715
# 150    13.857
# 173    -4.486
# Name: TAVG, dtype: float64
